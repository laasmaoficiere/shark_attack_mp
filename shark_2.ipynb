# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
shark_df = pd.read_excel(url)

# %%
shark_df.head(3)
# Out:
#           Date    Year        Type    Country       State            Location  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA  Queensland       Bargara Beach
# 1  04 Mar 2024  2024.0  Unprovoked        USA      Hawaii  Old Man's, Waikiki
# 2  02 Mar-2024  2024.0  Unprovoked        USA      Hawaii      Rainbows, Oahu
#
#    Activity            Name Sex  Age  \
# 0  Swimming  Brooklyn Sauer   F   13
# 1   Surfing   Matthew White   M  NaN
# 2  Swimming             NaN   F   11
#
#                                      Injury Unnamed: 11   Time  \
# 0  Minor injuries to back, abdomen and legs         NaN  16h00
# 1            No injury, shark bit surfboard           N    NaN
# 2                  Lacerations to left foot           N  13h30
#
#          Species                      Source  pdf href formula href  \
# 0     Tiger shark      Yahoo News, 3/15/2024  NaN          NaN  NaN
# 1  Tiger shark 8'          Surfer, 3/6/2024F  NaN          NaN  NaN
# 2  3' to 4' shark  Hawaii News Now, 3/4/2024  NaN          NaN  NaN
#
#   Case Number Case Number.1  original order Unnamed: 21 Unnamed: 22
# 0         NaN           NaN             NaN         NaN         NaN
# 1         NaN           NaN             NaN         NaN         NaN
# 2         NaN           NaN             NaN         NaN         NaN

# %%
#Data Description

#Date: when the attack happened
#Year: the year the attack happened
#Type: the type of shark attack, if it was provoked or unprovoked
#Country: country the attack happened
#State: country state the attack happened
#Location: location that occured the attack
#Activity: In which activity the attack happened
#Name: name of the person that suffered the attack
#Sex: gender of the person that suffered the attack
#Age: age of the person that suffered the attack
#Injury: the injury of the attack
#Time: the time that the attack happen
#Species: specie of shark that attacked
#Source: where this information came from
#pdf: PDF file of the description of the attack

#href formula:
#href:
#Case Number
#Case Number.1:
#Original Order:
#Unnamed: 11:
#Unnamed: 21:
#Unnamed: 22:

# %%
shark_df = shark_df.drop(columns = ['pdf', 'Unnamed: 11', 'href formula', 'href', 'Case Number', 'Case Number.1', 'original order', 'Source', 'Unnamed: 21', 'Unnamed: 22'])

# %%
shark_df
# Out:
#              Date    Year        Type    Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked  AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked        USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked        USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked  AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked      INDIA        Maharashtra
# ...           ...     ...         ...        ...                ...
# 6964          NaN     NaN         NaN        NaN                NaN
# 6965          NaN     NaN         NaN        NaN                NaN
# 6966          NaN     NaN         NaN        NaN                NaN
# 6967          NaN     NaN         NaN        NaN                NaN
# 6968          NaN     NaN         NaN        NaN                NaN
#
#                               Location  Activity                 Name  Sex  \
# 0                        Bargara Beach  Swimming       Brooklyn Sauer    F
# 1                   Old Man's, Waikiki   Surfing        Matthew White    M
# 2                       Rainbows, Oahu  Swimming                  NaN    F
# 3           Sandlnd Island, Jurian Bay       NaN               female    F
# 4     Vaitarna River, Palghar District   Fishing  Vicky Suresh Govari    M
# ...                                ...       ...                  ...  ...
# 6964                               NaN       NaN                  NaN  NaN
# 6965                               NaN       NaN                  NaN  NaN
# 6966                               NaN       NaN                  NaN  NaN
# 6967                               NaN       NaN                  NaN  NaN
# 6968                               NaN       NaN                  NaN  NaN
#
#       Age                                    Injury   Time        Species
# 0      13  Minor injuries to back, abdomen and legs  16h00     Tiger shark
# 1     NaN            No injury, shark bit surfboard    NaN  Tiger shark 8'
# 2      11                  Lacerations to left foot  13h30  3' to 4' shark
# 3      46                                Leg bitten  11h30     Tiger shark
# 4      32            Calf of lower left leg injured    NaN  Bull shark, 7'
# ...   ...                                       ...    ...             ...
# 6964  NaN                                       NaN    NaN             NaN
# 6965  NaN                                       NaN    NaN             NaN
# 6966  NaN                                       NaN    NaN             NaN
# 6967  NaN                                       NaN    NaN             NaN
# 6968  NaN                                       NaN    NaN             NaN
#
# [6969 rows x 13 columns]

# %%
shark_df = shark_df.dropna(how = 'all')

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0                           Bargara Beach      Swimming
# 1                      Old Man's, Waikiki       Surfing
# 2                          Rainbows, Oahu      Swimming
# 3              Sandlnd Island, Jurian Bay           NaN
# 4        Vaitarna River, Palghar District       Fishing
# ...                                   ...           ...
# 6939                          Roebuck Bay        Diving
# 6940                                  NaN  Pearl diving
# 6941                       Ocracoke Inlet      Swimming
# 6942                 Panama Bay 8ºN, 79ºW           NaN
# 6943  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  \
# 0            Brooklyn Sauer   F   13
# 1             Matthew White   M  NaN
# 2                       NaN   F   11
# 3                    female   F   46
# 4       Vicky Suresh Govari   M   32
# ...                     ...  ..  ...
# 6939                   male   M  NaN
# 6940                  Ahmun   M  NaN
# 6941  Coast Guard personnel   M  NaN
# 6942        Jules Patterson   M  NaN
# 6943                   male   M   15
#
#                                                  Injury   Time        Species
# 0              Minor injuries to back, abdomen and legs  16h00     Tiger shark
# 1                        No injury, shark bit surfboard    NaN  Tiger shark 8'
# 2                              Lacerations to left foot  13h30  3' to 4' shark
# 3                                            Leg bitten  11h30     Tiger shark
# 4                        Calf of lower left leg injured    NaN  Bull shark, 7'
# ...                                                 ...    ...             ...
# 6939                                              FATAL    NaN             NaN
# 6940                                              FATAL    NaN             NaN
# 6941                                              FATAL    NaN             NaN
# 6942                                              FATAL    NaN             NaN
# 6943  FATAL. "Shark bit him in half, carrying away t...    NaN             NaN
#
# [6944 rows x 13 columns]

# %%
shark_df["Country"].value_counts().head(10)
# Out:
# Country
# USA                 2538
# AUSTRALIA           1481
# SOUTH AFRICA         597
# NEW ZEALAND          144
# BAHAMAS              136
# PAPUA NEW GUINEA     136
# BRAZIL               122
# MEXICO               103
# ITALY                 72
# FIJI                  67
# Name: count, dtype: int64

# %%
shark_df["Year"].value_counts().head(20)
# Out:
# Year
# 2015.0    143
# 2017.0    139
# 2016.0    131
# 0.0       129
# 2011.0    128
# 2014.0    126
# 2018.0    124
# 2013.0    122
# 2008.0    122
# 2009.0    120
# 2012.0    117
# 2019.0    114
# 2007.0    113
# 2021.0    109
# 2023.0    108
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2020.0    101
# 2022.0     98
# Name: count, dtype: int64

# %%
shark_df["Date"].value_counts()
# Out:
# Date
# 1957           9
# 1942           8
# 1958           7
# No date        6
# 1956           6
#               ..
# 07-Jul-2000    1
# 09-Jul-2000    1
# 10-Jul-2000    1
# 12-Jul-2000    1
# 1845-1853      1
# Name: count, Length: 6003, dtype: int64

# %%
shark_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6944 entries, 0 to 6943
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6944 non-null   object
#  1   Year      6942 non-null   float64
#  2   Type      6926 non-null   object
#  3   Country   6894 non-null   object
#  4   State     6462 non-null   object
#  5   Location  6379 non-null   object
#  6   Activity  6358 non-null   object
#  7   Name      6724 non-null   object
#  8   Sex       6365 non-null   object
#  9   Age       3950 non-null   object
#  10  Injury    6909 non-null   object
#  11  Time      3418 non-null   object
#  12  Species   3812 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 759.5+ KB

# %%
shark_df.duplicated().sum()
# Out:
# 2

# %%
shark_df = shark_df.drop_duplicates()

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 0                           Bargara Beach      Swimming
# 1                      Old Man's, Waikiki       Surfing
# 2                          Rainbows, Oahu      Swimming
# 3              Sandlnd Island, Jurian Bay           NaN
# 4        Vaitarna River, Palghar District       Fishing
# ...                                   ...           ...
# 6939                          Roebuck Bay        Diving
# 6940                                  NaN  Pearl diving
# 6941                       Ocracoke Inlet      Swimming
# 6942                 Panama Bay 8ºN, 79ºW           NaN
# 6943  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex  Age  \
# 0            Brooklyn Sauer   F   13
# 1             Matthew White   M  NaN
# 2                       NaN   F   11
# 3                    female   F   46
# 4       Vicky Suresh Govari   M   32
# ...                     ...  ..  ...
# 6939                   male   M  NaN
# 6940                  Ahmun   M  NaN
# 6941  Coast Guard personnel   M  NaN
# 6942        Jules Patterson   M  NaN
# 6943                   male   M   15
#
#                                                  Injury   Time        Species
# 0              Minor injuries to back, abdomen and legs  16h00     Tiger shark
# 1                        No injury, shark bit surfboard    NaN  Tiger shark 8'
# 2                              Lacerations to left foot  13h30  3' to 4' shark
# 3                                            Leg bitten  11h30     Tiger shark
# 4                        Calf of lower left leg injured    NaN  Bull shark, 7'
# ...                                                 ...    ...             ...
# 6939                                              FATAL    NaN             NaN
# 6940                                              FATAL    NaN             NaN
# 6941                                              FATAL    NaN             NaN
# 6942                                              FATAL    NaN             NaN
# 6943  FATAL. "Shark bit him in half, carrying away t...    NaN             NaN
#
# [6942 rows x 13 columns]

# %%
shark_df['Year'].isna().value_counts()
# Out:
# Year
# False    6940
# True        2
# Name: count, dtype: int64

# %%
shark_df = shark_df.drop(columns = ["Name"])

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity Sex  Age  \
# 0                           Bargara Beach      Swimming   F   13
# 1                      Old Man's, Waikiki       Surfing   M  NaN
# 2                          Rainbows, Oahu      Swimming   F   11
# 3              Sandlnd Island, Jurian Bay           NaN   F   46
# 4        Vaitarna River, Palghar District       Fishing   M   32
# ...                                   ...           ...  ..  ...
# 6939                          Roebuck Bay        Diving   M  NaN
# 6940                                  NaN  Pearl diving   M  NaN
# 6941                       Ocracoke Inlet      Swimming   M  NaN
# 6942                 Panama Bay 8ºN, 79ºW           NaN   M  NaN
# 6943  Below the English fort, Trincomalee      Swimming   M   15
#
#                                                  Injury   Time        Species
# 0              Minor injuries to back, abdomen and legs  16h00     Tiger shark
# 1                        No injury, shark bit surfboard    NaN  Tiger shark 8'
# 2                              Lacerations to left foot  13h30  3' to 4' shark
# 3                                            Leg bitten  11h30     Tiger shark
# 4                        Calf of lower left leg injured    NaN  Bull shark, 7'
# ...                                                 ...    ...             ...
# 6939                                              FATAL    NaN             NaN
# 6940                                              FATAL    NaN             NaN
# 6941                                              FATAL    NaN             NaN
# 6942                                              FATAL    NaN             NaN
# 6943  FATAL. "Shark bit him in half, carrying away t...    NaN             NaN
#
# [6942 rows x 12 columns]

# %%
shark_df["Sex"].value_counts()
# Out:
# Sex
# M        5576
# F         779
# M           2
# N           2
#  M          1
# lli         1
# M x 2       1
# .           1
# Name: count, dtype: int64

# %%
gender_mapping = {
    'F': 'F',
    'lli': 'F',
    'M': 'M',
    'N': 'M',
    ' M': 'M',
    'M x 2': 'M',
    '.': 'F',
    'M ': 'M'
}
shark_df['Sex'] = shark_df['Sex'].replace(gender_mapping)

# %%
shark_df["Sex"].value_counts()
# Out:
# Sex
# M    5582
# F     781
# Name: count, dtype: int64

# %%
shark_df["Activity"].value_counts().head(20)
# Out:
# Activity
# Surfing            1121
# Swimming            976
# Fishing             488
# Spearfishing        381
# Wading              174
# Bathing             163
# Diving              141
# Snorkeling          129
# Standing            113
# Scuba diving         84
# Body boarding        63
# Body surfing         50
# Swimming             47
# Boogie boarding      42
# Kayaking             39
# Free diving          33
# Treading water       33
# Fell overboard       32
# Pearl diving         32
# Windsurfing          20
# Name: count, dtype: int64

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity Sex  Age  \
# 0                           Bargara Beach      Swimming   F   13
# 1                      Old Man's, Waikiki       Surfing   M  NaN
# 2                          Rainbows, Oahu      Swimming   F   11
# 3              Sandlnd Island, Jurian Bay           NaN   F   46
# 4        Vaitarna River, Palghar District       Fishing   M   32
# ...                                   ...           ...  ..  ...
# 6939                          Roebuck Bay        Diving   M  NaN
# 6940                                  NaN  Pearl diving   M  NaN
# 6941                       Ocracoke Inlet      Swimming   M  NaN
# 6942                 Panama Bay 8ºN, 79ºW           NaN   M  NaN
# 6943  Below the English fort, Trincomalee      Swimming   M   15
#
#                                                  Injury   Time        Species
# 0              Minor injuries to back, abdomen and legs  16h00     Tiger shark
# 1                        No injury, shark bit surfboard    NaN  Tiger shark 8'
# 2                              Lacerations to left foot  13h30  3' to 4' shark
# 3                                            Leg bitten  11h30     Tiger shark
# 4                        Calf of lower left leg injured    NaN  Bull shark, 7'
# ...                                                 ...    ...             ...
# 6939                                              FATAL    NaN             NaN
# 6940                                              FATAL    NaN             NaN
# 6941                                              FATAL    NaN             NaN
# 6942                                              FATAL    NaN             NaN
# 6943  FATAL. "Shark bit him in half, carrying away t...    NaN             NaN
#
# [6942 rows x 12 columns]

# %%
shark_df = shark_df.drop(columns = ["Location", "Date"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 shark_df = shark_df.drop(columns = ["Location", "Date"])
#
# File c:\Users\reetu\anaconda3\Lib\site-packages\pandas\core\frame.py:5344, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5196 def drop(
#    5197     self,
#    5198     labels: IndexLabel | None = None,
#    (...)
#    5205     errors: IgnoreRaise = "raise",
#    5206 ) -> DataFrame | None:
#    5207     """
#    5208     Drop specified labels from rows or columns.
#    5209
#    (...)
#    5342             weight  1.0     0.8
#    5343     """
# -> 5344     return super().drop(
#    5345         labels=labels,
#    5346         axis=axis,
#    5347         index=index,
#    5348         columns=columns,
#    5349         level=level,
#    5350         inplace=inplace,
#    5351         errors=errors,
#    5352     )
#
# File c:\Users\reetu\anaconda3\Lib\site-packages\pandas\core\generic.py:4711, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4709 for axis, labels in axes.items():
#    4710     if labels is not None:
# -> 4711         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4713 if inplace:
#    4714     self._update_inplace(obj)
#
# File c:\Users\reetu\anaconda3\Lib\site-packages\pandas\core\generic.py:4753, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4751         new_axis = axis.drop(labels, level=level, errors=errors)
#    4752     else:
# -> 4753         new_axis = axis.drop(labels, errors=errors)
#    4754     indexer = axis.get_indexer(new_axis)
#    4756 # Case for non-unique axis
#    4757 else:
#
# File c:\Users\reetu\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:7000, in Index.drop(self, labels, errors)
#    6998 if mask.any():
#    6999     if errors != "ignore":
# -> 7000         raise KeyError(f"{labels[mask].tolist()} not found in axis")
#    7001     indexer = indexer[~mask]
#    7002 return self.delete(indexer)
#
# KeyError: "['Location', 'Date'] not found in axis"

# %%
shark_df
# Out:
#         Year        Type             Country              State      Activity  \
# 0     2024.0  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024.0  Unprovoked                 USA             Hawaii       Surfing
# 2     2024.0  Unprovoked                 USA             Hawaii      Swimming
# 3     2024.0  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024.0  Unprovoked               INDIA        Maharashtra       Fishing
# ...      ...         ...                 ...                ...           ...
# 6939     0.0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0.0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0.0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0.0  Unprovoked              PANAMA                NaN           NaN
# 6943     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
#      Sex  Age                                             Injury   Time  \
# 0      F   13           Minor injuries to back, abdomen and legs  16h00
# 1      M  NaN                     No injury, shark bit surfboard    NaN
# 2      F   11                           Lacerations to left foot  13h30
# 3      F   46                                         Leg bitten  11h30
# 4      M   32                     Calf of lower left leg injured    NaN
# ...   ..  ...                                                ...    ...
# 6939   M  NaN                                              FATAL    NaN
# 6940   M  NaN                                              FATAL    NaN
# 6941   M  NaN                                              FATAL    NaN
# 6942   M  NaN                                              FATAL    NaN
# 6943   M   15  FATAL. "Shark bit him in half, carrying away t...    NaN
#
#             Species
# 0        Tiger shark
# 1     Tiger shark 8'
# 2     3' to 4' shark
# 3        Tiger shark
# 4     Bull shark, 7'
# ...              ...
# 6939             NaN
# 6940             NaN
# 6941             NaN
# 6942             NaN
# 6943             NaN
#
# [6942 rows x 10 columns]

# %%
shark_df['Year'].isna().sum()
# Out:
# 2

# %%
shark_df['Year'].unique()
# Out:
# array([2024, 2023, 2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014,
#        2013, 2012, 2011, 2010, 2009, 2008, 2007, 2006, 2005, 2004, 2003,
#        2002, 2001, 2000, 1999, 1998, 1997, 1996, 1995, 1984, 1994, 1993,
#        1992, 1991, 1990, 1989, 1969, 1988, 1987, 1986, 1985, 1983, 1982,
#        1981, 1980, 1979, 1978, 1977, 1976, 1975, 1974, 1973, 1972, 1971,
#        1970, 1968, 1967, 1966, 1965, 1964, 1963, 1962, 1961, 1960, 1959,
#        1958, 1957, 1956, 1955, 1954, 1953, 1952, 1951, 1950, 1949, 1948,
#        1848, 1947, 1946, 1945, 1944, 1943, 1942, 1941, 1940, 1939, 1938,
#        1937, 1936, 1935, 1934, 1933, 1932, 1931, 1930, 1929, 1928, 1927,
#        1926, 1925, 1924, 1923, 1922, 1921, 1920, 1919, 1918, 1917, 1916,
#        1915, 1914, 1913, 1912, 1911, 1910, 1909, 1908, 1907, 1906, 1905,
#        1904, 1903, 1902, 1901, 1900, 1899, 1898, 1897, 1896, 1895, 1894,
#        1893, 1892, 1891, 1890, 1889, 1888, 1887, 1886, 1885, 1884, 1883,
#        1882, 1881, 1880, 1879, 1878, 1877, 1876, 1875, 1874, 1873, 1872,
#        1871, 1870, 1869, 1868, 1867, 1866, 1865, 1864, 1863, 1862, 1861,
#        1860, 1859, 1858, 1857, 1856, 1855, 1853, 1852, 1851, 1850, 1849,
#        1847, 1846, 1845, 1844, 1842, 1841, 1840, 1839, 1837, 1836, 1835,
#        1834, 1832, 1831, 1830, 1829, 1828, 1827, 1826, 1825, 1823, 1822,
#        1819, 1818, 1817, 1816, 1815, 1812, 1811, 1810, 1808, 1807, 1805,
#        1804, 1803, 1802, 1801, 1800, 1797, 1792, 1791, 1788, 1787, 1786,
#        1785, 1784, 1783, 1780, 1779, 1776, 1771, 1767, 1764, 1758, 1753,
#        1751, 1749, 1755, 1748, 1742, 1738, 1733, 1723, 1721, 1703, 1700,
#        1642, 1691, 1640, 1638, 1637, 1617, 1595, 1580, 1555, 1554, 1543,
#        1518, 1500, 1000,   77,    5,    0])

# %%
filtered_df = shark_df[(shark_df['Year'] >= 2000) & (shark_df['Year'] <= 2024)]

# %%
filtered_df['Activity'].value_counts().head()
# Out:
# Activity
# Surfing         779
# Swimming        388
# Fishing         168
# Spearfishing    164
# Snorkeling      111
# Name: count, dtype: int64

# %%
shark_df = shark_df.dropna(subset = ['Year'])

# %%
shark_df['Year'] = shark_df['Year'].astype(int)
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_9808\604342177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Year'] = shark_df['Year'].astype(int)

# %%
shark_df["Country"].isna().sum()
# Out:
# 50

# %%
top5_countries_attacks = shark_df["Country"].value_counts().head(5)
top5_countries_attacks
# Out:
# Country
# USA             2537
# AUSTRALIA       1480
# SOUTH AFRICA     597
# NEW ZEALAND      144
# BAHAMAS          136
# Name: count, dtype: int64

# %%
shark_df["Injury"].value_counts()
# Out:
# Injury
# FATAL                                                                                        862
# Foot bitten                                                                                  100
# Survived                                                                                      97
# No injury                                                                                     85
# Leg bitten                                                                                    81
#                                                                                             ...
# Multiple bites to foot after jumping off surfboard onto shark PROVOKED INCIDENT                1
# Shallow  lacerations to left  thigh PROVOKED INCIDENT                                          1
# Bitten on finger                                                                               1
# Hand & foot lacerated,  lower left leg severely bitten, necessitating surgical amputation      1
# FATAL. "Shark bit him in half, carrying away the lower extremities"                            1
# Name: count, Length: 4078, dtype: int64

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
#      Sex  Age                                             Injury   Time  \
# 0      F   13           Minor injuries to back, abdomen and legs  16h00
# 1      M  NaN                     No injury, shark bit surfboard    NaN
# 2      F   11                           Lacerations to left foot  13h30
# 3      F   46                                         Leg bitten  11h30
# 4      M   32                     Calf of lower left leg injured    NaN
# ...   ..  ...                                                ...    ...
# 6939   M  NaN                                              FATAL    NaN
# 6940   M  NaN                                              FATAL    NaN
# 6941   M  NaN                                              FATAL    NaN
# 6942   M  NaN                                              FATAL    NaN
# 6943   M   15  FATAL. "Shark bit him in half, carrying away t...    NaN
#
#             Species   is_fatal
# 0        Tiger shark     False
# 1     Tiger shark 8'     False
# 2     3' to 4' shark     False
# 3        Tiger shark     False
# 4     Bull shark, 7'     False
# ...              ...       ...
# 6939             NaN      True
# 6940             NaN      True
# 6941             NaN      True
# 6942             NaN      True
# 6943             NaN      True
#
# [6940 rows x 11 columns]

# %%
type_mapping= {
    'Unprovoked': 'Unprovoked', 'Provoked': 'Provoked', 'Invalid': 'Others', 'Watercraft':'Others',
    'Sea Disaster':'Others', 'Questionable':'Others'
}
shark_df['Type'] = shark_df['Type'].map(type_mapping)
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_9808\722582336.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Type'] = shark_df['Type'].map(type_mapping)

# %%
# import re

# def check_string(shark_df, search_string="FATAL", column_name='Injury'):
#     if shark_df[column_name].str.contains(search_string, flags=re.IGNORECASE, regex=True).any():
#         print("Found")
#     else: print("Not found")

# %%
import re

def check_str(main_string, search_string):

    return bool(re.search(main_string.lower(), str(search_string).lower()))

# %%
print(check_str("fatal","Hey, i fave a injury"))
# Out:
# False

# %%
# def map_keyword(value):
#     if 'FATAL' in value:
#         return 'FATAL'
#     else:
#         return 'Non FATAL'
shark_df['is_fatal'] = shark_df['Injury'].apply(lambda x: check_str("fatal", x))
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_9808\3392692585.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['is_fatal'] = shark_df['Injury'].apply(lambda x: check_str("fatal", x))

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
#      Sex  Age                                             Injury   Time  \
# 0      F   13           Minor injuries to back, abdomen and legs  16h00
# 1      M  NaN                     No injury, shark bit surfboard    NaN
# 2      F   11                           Lacerations to left foot  13h30
# 3      F   46                                         Leg bitten  11h30
# 4      M   32                     Calf of lower left leg injured    NaN
# ...   ..  ...                                                ...    ...
# 6939   M  NaN                                              FATAL    NaN
# 6940   M  NaN                                              FATAL    NaN
# 6941   M  NaN                                              FATAL    NaN
# 6942   M  NaN                                              FATAL    NaN
# 6943   M   15  FATAL. "Shark bit him in half, carrying away t...    NaN
#
#             Species   is_fatal
# 0        Tiger shark     False
# 1     Tiger shark 8'     False
# 2     3' to 4' shark     False
# 3        Tiger shark     False
# 4     Bull shark, 7'     False
# ...              ...       ...
# 6939             NaN      True
# 6940             NaN      True
# 6941             NaN      True
# 6942             NaN      True
# 6943             NaN      True
#
# [6940 rows x 11 columns]

# %%
shark_df["Time"].value_counts().head(10)
# Out:
# Time
# Afternoon    215
# 11h00        140
# Morning      135
# 15h00        127
# 16h00        123
# 12h00        122
# 14h00        115
# 16h30         88
# 13h00         85
# 17h30         83
# Name: count, dtype: int64

# %%
type_mapping= { 'Invalid': 'Others', 'Watercraft':'Others',
    'Sea Disaster':'Others', 'Questionable':'Others'
}
shark_df['Type'] = shark_df['Type'].map(type_mapping)
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_9808\773706611.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Type'] = shark_df['Type'].map(type_mapping)

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
#      Sex  Age                                             Injury   Time  \
# 0      F   13           Minor injuries to back, abdomen and legs  16h00
# 1      M  NaN                     No injury, shark bit surfboard    NaN
# 2      F   11                           Lacerations to left foot  13h30
# 3      F   46                                         Leg bitten  11h30
# 4      M   32                     Calf of lower left leg injured    NaN
# ...   ..  ...                                                ...    ...
# 6939   M  NaN                                              FATAL    NaN
# 6940   M  NaN                                              FATAL    NaN
# 6941   M  NaN                                              FATAL    NaN
# 6942   M  NaN                                              FATAL    NaN
# 6943   M   15  FATAL. "Shark bit him in half, carrying away t...    NaN
#
#             Species   is_fatal
# 0        Tiger shark     False
# 1     Tiger shark 8'     False
# 2     3' to 4' shark     False
# 3        Tiger shark     False
# 4     Bull shark, 7'     False
# ...              ...       ...
# 6939             NaN      True
# 6940             NaN      True
# 6941             NaN      True
# 6942             NaN      True
# 6943             NaN      True
#
# [6940 rows x 11 columns]

# %%
shark_df.drop(columns = ['Species '])
# Out:
#       Year Type             Country              State      Activity Sex  Age  \
# 0     2024  NaN           AUSTRALIA         Queensland      Swimming   F   13
# 1     2024  NaN                 USA             Hawaii       Surfing   M  NaN
# 2     2024  NaN                 USA             Hawaii      Swimming   F   11
# 3     2024  NaN           AUSTRALIA  Western Australia           NaN   F   46
# 4     2024  NaN               INDIA        Maharashtra       Fishing   M   32
# ...    ...  ...                 ...                ...           ...  ..  ...
# 6939     0  NaN           AUSTRALIA  Western Australia        Diving   M  NaN
# 6940     0  NaN           AUSTRALIA  Western Australia  Pearl diving   M  NaN
# 6941     0  NaN                 USA     North Carolina      Swimming   M  NaN
# 6942     0  NaN              PANAMA                NaN           NaN   M  NaN
# 6943     0  NaN  CEYLON (SRI LANKA)   Eastern Province      Swimming   M   15
#
#                                                  Injury   Time  is_fatal
# 0              Minor injuries to back, abdomen and legs  16h00     False
# 1                        No injury, shark bit surfboard    NaN     False
# 2                              Lacerations to left foot  13h30     False
# 3                                            Leg bitten  11h30     False
# 4                        Calf of lower left leg injured    NaN     False
# ...                                                 ...    ...       ...
# 6939                                              FATAL    NaN      True
# 6940                                              FATAL    NaN      True
# 6941                                              FATAL    NaN      True
# 6942                                              FATAL    NaN      True
# 6943  FATAL. "Shark bit him in half, carrying away t...    NaN      True
#
# [6940 rows x 10 columns]

# %%
df_shark.Year.value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 df_shark.Year.value_counts()
#
# NameError: name 'df_shark' is not defined

# %%
shark_df['is_fatal'] = shark_df['is_fatal'].map({True: 'Fatal', False:'Non_Fatal'})
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_12084\1749171565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['is_fatal'] = shark_df['is_fatal'].map({True: 'Fatal', False:'Non_Fatal'})

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
#      Sex  Age                                             Injury   Time  \
# 0      F   13           Minor injuries to back, abdomen and legs  16h00
# 1      M  NaN                     No injury, shark bit surfboard    NaN
# 2      F   11                           Lacerations to left foot  13h30
# 3      F   46                                         Leg bitten  11h30
# 4      M   32                     Calf of lower left leg injured    NaN
# ...   ..  ...                                                ...    ...
# 6939   M  NaN                                              FATAL    NaN
# 6940   M  NaN                                              FATAL    NaN
# 6941   M  NaN                                              FATAL    NaN
# 6942   M  NaN                                              FATAL    NaN
# 6943   M   15  FATAL. "Shark bit him in half, carrying away t...    NaN
#
#             Species    is_fatal
# 0        Tiger shark  Non_Fatal
# 1     Tiger shark 8'  Non_Fatal
# 2     3' to 4' shark  Non_Fatal
# 3        Tiger shark  Non_Fatal
# 4     Bull shark, 7'  Non_Fatal
# ...              ...        ...
# 6939             NaN      Fatal
# 6940             NaN      Fatal
# 6941             NaN      Fatal
# 6942             NaN      Fatal
# 6943             NaN      Fatal
#
# [6940 rows x 11 columns]

# %%
df_shark_sliced_age = shark_df.iloc[0:1000]
df_shark_sliced_age
# Out:
#       Year        Type     Country              State  \
# 0     2024  Unprovoked   AUSTRALIA         Queensland
# 1     2024  Unprovoked         USA             Hawaii
# 2     2024  Unprovoked         USA             Hawaii
# 3     2024  Unprovoked   AUSTRALIA  Western Australia
# 4     2024  Unprovoked       INDIA        Maharashtra
# ...    ...         ...         ...                ...
# 996   2015  Unprovoked  COSTA RICA         Guanacaste
# 997   2015         NaN   AUSTRALIA           Victoria
# 998   2015  Unprovoked         USA            Florida
# 999   2015      Others         USA     South Carolina
# 1000  2015  Unprovoked   AUSTRALIA           Tasmania
#
#                       Activity Sex  Age  \
# 0                     Swimming   F   13
# 1                      Surfing   M  NaN
# 2                     Swimming   F   11
# 3                          NaN   F   46
# 4                      Fishing   M   32
# ...                        ...  ..  ...
# 996                    Surfing   M   47
# 997                    Surfing   M   40
# 998                    Surfing   M   25
# 999                   Floating   F   35
# 1000  Scallop diving on hookah   M   46
#
#                                                  Injury   Time  \
# 0              Minor injuries to back, abdomen and legs  16h00
# 1                        No injury, shark bit surfboard    NaN
# 2                              Lacerations to left foot  13h30
# 3                                            Leg bitten  11h30
# 4                        Calf of lower left leg injured    NaN
# ...                                                 ...    ...
# 996                               Minor inuries to toes    NaN
# 997                                      Injury to hand    NaN
# 998                        Minor injury to sole of foot  19h00
# 999   2' cut to dorsum of foot, 2 puncture wounds to...  10h10
# 1000                                              FATAL  10h00
#
#                                                Species   is_fatal
# 0                                           Tiger shark     False
# 1                                        Tiger shark 8'     False
# 2                                        3' to 4' shark     False
# 3                                           Tiger shark     False
# 4                                        Bull shark, 7'     False
# ...                                                 ...       ...
# 996                                                 NaN     False
# 997                                                 NaN     False
# 998                       Blacktip or spinner shark, 4'     False
# 999   Thought to involve a 3' to 4' shark, but shark...     False
# 1000                          White shark, 3.9 to 4.2 m      True
#
# [1000 rows x 11 columns]

# %%
df_shark['Species'] = df_shark['Species '].str.strip()
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_18336\1133699071.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced['Species'] = df_shark_sliced['Species '].str.strip()

# %%
df_shark_sliced_age['Species'].isnull().sum()
# Out:
# 427

# %%
df_shark_sliced_age['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 1000 entries, 0 to 1000
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 752 non-null    object
# dtypes: object(1)
# memory usage: 15.6+ KB

# %%
df_shark_sliced_age['Age'] = pd.to_numeric(df_shark_sliced_age['Age'], errors='coerce')
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_18336\994537905.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced['Age'] = pd.to_numeric(df_shark_sliced['Age'], errors='coerce')

# %%
df_shark_sliced_age['Age'].dtype
# Out:
# dtype('float64')

# %%
df_shark_sliced_age['Age'].isna().sum()
# Out:
# 284

# %%
df_shark_sliced_age['Age'] = df_shark_sliced['Age'].fillna(df_shark_sliced['Age'].mean())
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_18336\532892135.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced['Age'] = df_shark_sliced['Age'].fillna(df_shark_sliced['Age'].mean())

# %%
df_shark_sliced_age['Age'].astype(int)
# Out:
# 0       13
# 1       32
# 2       11
# 3       46
# 4       32
#         ..
# 996     47
# 997     40
# 998     25
# 999     35
# 1000    46
# Name: Age, Length: 1000, dtype: int32

# %%
bins= [0, 12, 19, 60, 100]
labels = ['Child', 'Teen', 'Adult', 'Senior']
df_shark_sliced_age['age_group'] = pd.cut(df_shark_sliced_age['Age'],bins=bins, labels=labels,right=True)
# Out:
# C:\Users\reetu\AppData\Local\Temp\ipykernel_18336\3003664353.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced['age_group'] = pd.cut(df_shark_sliced['Age'],bins=bins, labels=labels,right=True)

# %%
df_shark_sliced_age
# Out:
#       Year        Type     Country              State  \
# 0     2024  Unprovoked   AUSTRALIA         Queensland
# 1     2024  Unprovoked         USA             Hawaii
# 2     2024  Unprovoked         USA             Hawaii
# 3     2024  Unprovoked   AUSTRALIA  Western Australia
# 4     2024  Unprovoked       INDIA        Maharashtra
# ...    ...         ...         ...                ...
# 996   2015  Unprovoked  COSTA RICA         Guanacaste
# 997   2015         NaN   AUSTRALIA           Victoria
# 998   2015  Unprovoked         USA            Florida
# 999   2015      Others         USA     South Carolina
# 1000  2015  Unprovoked   AUSTRALIA           Tasmania
#
#                       Activity Sex        Age  \
# 0                     Swimming   F  13.000000
# 1                      Surfing   M  32.768156
# 2                     Swimming   F  11.000000
# 3                          NaN   F  46.000000
# 4                      Fishing   M  32.000000
# ...                        ...  ..        ...
# 996                    Surfing   M  47.000000
# 997                    Surfing   M  40.000000
# 998                    Surfing   M  25.000000
# 999                   Floating   F  35.000000
# 1000  Scallop diving on hookah   M  46.000000
#
#                                                  Injury   Time  \
# 0              Minor injuries to back, abdomen and legs  16h00
# 1                        No injury, shark bit surfboard    NaN
# 2                              Lacerations to left foot  13h30
# 3                                            Leg bitten  11h30
# 4                        Calf of lower left leg injured    NaN
# ...                                                 ...    ...
# 996                               Minor inuries to toes    NaN
# 997                                      Injury to hand    NaN
# 998                        Minor injury to sole of foot  19h00
# 999   2' cut to dorsum of foot, 2 puncture wounds to...  10h10
# 1000                                              FATAL  10h00
#
#                                                Species   is_fatal  \
# 0                                           Tiger shark     False
# 1                                        Tiger shark 8'     False
# 2                                        3' to 4' shark     False
# 3                                           Tiger shark     False
# 4                                        Bull shark, 7'     False
# ...                                                 ...       ...
# 996                                                 NaN     False
# 997                                                 NaN     False
# 998                       Blacktip or spinner shark, 4'     False
# 999   Thought to involve a 3' to 4' shark, but shark...     False
# 1000                          White shark, 3.9 to 4.2 m      True
#
#                                                 Species age_group
# 0                                           Tiger shark      Teen
# 1                                        Tiger shark 8'     Adult
# 2                                        3' to 4' shark     Child
# 3                                           Tiger shark     Adult
# 4                                        Bull shark, 7'     Adult
# ...                                                 ...       ...
# 996                                                 NaN     Adult
# 997                                                 NaN     Adult
# 998                       Blacktip or spinner shark, 4'     Adult
# 999   Thought to involve a 3' to 4' shark, but shark...     Adult
# 1000                          White shark, 3.9 to 4.2 m     Adult
#
# [1000 rows x 13 columns]

# %%
df_shark_sliced_age['age_group'].value_counts()
# Out:
# age_group
# Adult     743
# Teen      124
# Child      83
# Senior     50
# Name: count, dtype: int64

# %%
Values = [83, 124, 743, 50]
Categories = ['Child', 'Teen', 'Adult', 'Senior']

# %%
plt.bar(Categories, Values)
# Out:
# <BarContainer object of 4 artists>

# %%
pivot_df_shark = df_shark.pivot_table(index = "Injury", )
