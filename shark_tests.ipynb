# %%
import pandas as pd
pd.set_option('display.max_columns', None)
url = 'https://www.sharkattackfile.net/spreadsheets/GSAF5.xls'
shark_df = pd.read_excel(url)

# %%
shark_df.head(3)
# Out:
#           Date    Year        Type    Country       State            Location  \
# 0  15 Mar 2024  2024.0  Unprovoked  AUSTRALIA  Queensland       Bargara Beach
# 1  04 Mar 2024  2024.0  Unprovoked        USA      Hawaii  Old Man's, Waikiki
# 2  02 Mar-2024  2024.0  Unprovoked        USA      Hawaii      Rainbows, Oahu
#
#    Activity            Name Sex  Age  \
# 0  Swimming  Brooklyn Sauer   F   13
# 1   Surfing   Matthew White   M  NaN
# 2  Swimming             NaN   F   11
#
#                                      Injury Unnamed: 11   Time  \
# 0  Minor injuries to back, abdomen and legs         NaN  16h00
# 1            No injury, shark bit surfboard           N    NaN
# 2                  Lacerations to left foot           N  13h30
#
#          Species                      Source  pdf href formula href  \
# 0     Tiger shark      Yahoo News, 3/15/2024  NaN          NaN  NaN
# 1  Tiger shark 8'          Surfer, 3/6/2024F  NaN          NaN  NaN
# ...

# %%
#Data Description

#Date: when the attack happened
#Year: the year the attack happened
#Type: the type of shark attack, if it was provoked or unprovoked
#Country: country the attack happened
#State: country state the attack happened
#Location: location that occured the attack
#Activity: In which activity the attack happened
#Name: name of the person that suffered the attack
#Sex: gender of the person that suffered the attack
#Age: age of the person that suffered the attack
#Injury: the injury of the attack
#Time: the time that the attack happen
#Species: specie of shark that attacked
#Source: where this information came from
#pdf: PDF file of the description of the attack

#href formula:
#href:
#Case Number
#Case Number.1:
#Original Order:
#Unnamed: 11:
#Unnamed: 21:
#Unnamed: 22:

# %%
shark_df = shark_df.drop(columns = ['Name', 'pdf', 'Unnamed: 11', 'href formula', 'href', 'Case Number', 'Case Number.1', 'original order', 'Source', 'Unnamed: 21', 'Unnamed: 22')
# Out:
#   Cell In[134], line 1
#     shark_df = shark_df.drop(columns = ['Name', 'pdf', 'Unnamed: 11', 'href formula', 'href', 'Case Number', 'Case Number.1', 'original order', 'Source', 'Unnamed: 21', 'Unnamed: 22')
#                                                                                                                                                                                       ^
# SyntaxError: closing parenthesis ')' does not match opening parenthesis '['

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
shark_df = shark_df.dropna(how = 'all')

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
shark_df["Country"].value_counts().head(10)
# Out:
# Country
# USA                 2538
# AUSTRALIA           1481
# SOUTH AFRICA         597
# NEW ZEALAND          144
# BAHAMAS              136
# PAPUA NEW GUINEA     136
# BRAZIL               122
# MEXICO               103
# ITALY                 72
# FIJI                  67
# Name: count, dtype: int64

# %%
shark_df["Year"].value_counts().head(20)
# Out:
# Year
# 2015.0    143
# 2017.0    139
# 2016.0    131
# 0.0       129
# 2011.0    128
# 2014.0    126
# 2018.0    124
# 2013.0    122
# 2008.0    122
# 2009.0    120
# 2012.0    117
# 2019.0    114
# 2007.0    113
# 2021.0    109
# 2023.0    108
# 2006.0    103
# 2005.0    103
# 2010.0    101
# 2020.0    101
# 2022.0     98
# Name: count, dtype: int64

# %%
shark_df["Date"].value_counts()
# Out:
# Date
# 1957           9
# 1942           8
# 1958           7
# No date        6
# 1956           6
#               ..
# 07-Jul-2000    1
# 09-Jul-2000    1
# 10-Jul-2000    1
# 12-Jul-2000    1
# 1845-1853      1
# Name: count, Length: 6003, dtype: int64

# %%
shark_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 6944 entries, 0 to 6943
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      6944 non-null   object
#  1   Year      6942 non-null   float64
#  2   Type      6926 non-null   object
#  3   Country   6894 non-null   object
#  4   State     6462 non-null   object
#  5   Location  6379 non-null   object
#  6   Activity  6358 non-null   object
#  7   Name      6724 non-null   object
#  8   Sex       6365 non-null   object
#  9   Age       3950 non-null   object
#  10  Injury    6909 non-null   object
#  11  Time      3418 non-null   object
#  12  Species   3812 non-null   object
# dtypes: float64(1), object(12)
# memory usage: 759.5+ KB

# %%
shark_df.duplicated().sum()
# Out:
# 2

# %%
shark_df = shark_df.drop_duplicates()

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
shark_df['Year'].isna().value_counts()
# Out:
# Year
# False    6940
# True        2
# Name: count, dtype: int64

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
shark_df["Sex"].value_counts()
# Out:
# Sex
# M        5576
# F         779
# M           2
# N           2
#  M          1
# lli         1
# M x 2       1
# .           1
# Name: count, dtype: int64

# %%
gender_mapping = {
    'F': 'F',
    'lli': 'F',
    'M': 'M',
    'N': 'M',
    ' M': 'M',
    'M x 2': 'M',
    '.': 'F',
    'M ': 'M'
}
shark_df['Sex'] = shark_df['Sex'].replace(gender_mapping)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\2694764508.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Sex'] = shark_df['Sex'].replace(gender_mapping)

# %%
shark_df["Sex"].value_counts()
# Out:
# Sex
# M    5582
# F     781
# Name: count, dtype: int64

# %%
shark_df["Activity"].value_counts().head(20)
# Out:
# Activity
# Surfing            1121
# Swimming            976
# Fishing             488
# Spearfishing        381
# Wading              174
# Bathing             163
# Diving              141
# Snorkeling          129
# Standing            113
# Scuba diving         84
# Body boarding        63
# Body surfing         50
# Swimming             47
# Boogie boarding      42
# Kayaking             39
# Free diving          33
# Treading water       33
# Fell overboard       32
# Pearl diving         32
# Windsurfing          20
# Name: count, dtype: int64

# %%
shark_df
# Out:
#              Date    Year        Type             Country              State  \
# 0     15 Mar 2024  2024.0  Unprovoked           AUSTRALIA         Queensland
# 1     04 Mar 2024  2024.0  Unprovoked                 USA             Hawaii
# 2     02 Mar-2024  2024.0  Unprovoked                 USA             Hawaii
# 3     25 Feb-2024  2024.0  Unprovoked           AUSTRALIA  Western Australia
# 4     14 Feb-2024  2024.0  Unprovoked               INDIA        Maharashtra
# ...           ...     ...         ...                 ...                ...
# 6939  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6940  Before 1903     0.0  Unprovoked           AUSTRALIA  Western Australia
# 6941    1900-1905     0.0  Unprovoked                 USA     North Carolina
# 6942    1883-1889     0.0  Unprovoked              PANAMA                NaN
# 6943    1845-1853     0.0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
# ...

# %%
shark_df = shark_df.drop(columns = ["Species ", "Location", "Date"])

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
shark_df['Year'].isna().sum()
# Out:
# 2

# %%
shark_df = shark_df.dropna(subset = ['Year'])

# %%
shark_df['Year'] = shark_df['Year'].astype(int)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\604342177.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Year'] = shark_df['Year'].astype(int)

# %%
shark_df["Country"].isna().sum()
# Out:
# 50

# %%
top5_countries_attacks = shark_df["Country"].value_counts().head(5)
top5_countries_attacks
# Out:
# Country
# USA             2537
# AUSTRALIA       1480
# SOUTH AFRICA     597
# NEW ZEALAND      144
# BAHAMAS          136
# Name: count, dtype: int64

# %%
shark_df["Injury"].value_counts()
# Out:
# Injury
# FATAL                                                                                        859
# Foot bitten                                                                                  100
# Survived                                                                                      96
# No injury                                                                                     85
# Leg bitten                                                                                    81
#                                                                                             ...
# Multiple bites to foot after jumping off surfboard onto shark PROVOKED INCIDENT                1
# Shallow  lacerations to left  thigh PROVOKED INCIDENT                                          1
# Bitten on finger                                                                               1
# Hand & foot lacerated,  lower left leg severely bitten, necessitating surgical amputation      1
# ...

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
type_mapping= {
    'Unprovoked': 'Unprovoked', 'Provoked': 'Provoked', 'Invalid': 'Others', 'Watercraft':'Others',
    'Sea Disaster':'Others', 'Questionable':'Others'
}
shark_df['Type'] = shark_df['Type'].map(type_mapping)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\722582336.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Type'] = shark_df['Type'].map(type_mapping)

# %%
shark_df_sliced = shark_df[:500]

# %%
shark_df_sliced["Age"].isna().sum()
# Out:
# 122

# %%
# import re

# def check_string(shark_df, search_string="FATAL", column_name='Injury'):
#     if shark_df[column_name].str.contains(search_string, flags=re.IGNORECASE, regex=True).any():
#         print("Found")
#     else: print("Not found")

# %%
import re

def check_str(main_string, search_string):

    return bool(re.search(main_string.lower(), str(search_string).lower()))

# %%
print(check_str("fatal","Hey, i fave a injury"))
# Out:
# False

# %%
# def map_keyword(value):
#     if 'FATAL' in value:
#         return 'FATAL'
#     else:
#         return 'Non FATAL'
shark_df['is_fatal'] = shark_df['Injury'].apply(lambda x: check_str("fatal", x))
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\3392692585.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['is_fatal'] = shark_df['Injury'].apply(lambda x: check_str("fatal", x))

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
shark_df["Time"].value_counts().head(10)
# Out:
# Time
# Afternoon    215
# 11h00        140
# Morning      135
# 15h00        127
# 16h00        123
# 12h00        122
# 14h00        115
# 16h30         88
# 13h00         85
# 17h30         83
# Name: count, dtype: int64

# %%
type_mapping= {
    'Unprovoked': 'Unprovoked', 'Provoked': 'Provoked', 'Invalid': 'Others', 'Watercraft':'Others',
    'Sea Disaster':'Others', 'Questionable':'Others'
}
shark_df['Type'] = shark_df['Type'].map(type_mapping)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\722582336.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Type'] = shark_df['Type'].map(type_mapping)

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
time_mapping= {
    '00h00': 'Night',
    '01h00': 'Night',
    '02h00': 'Night',
    '03h00': 'Night',
    '04h00': 'Night',
    '05h00': 'Morning',
    '06h00': 'Morning',
    '07h00': 'Morning',
    '08h00': 'Morning',
    '09h00': 'Morning',
    '10h00': 'Morning',
    '11h00': 'Morning',
    '12h00': 'Morning',
    '13h00': 'Afternoon',
    '14h00': 'Afternoon',
    '15h00': 'Afternoon',
    '16h00': 'Afternoon',
    '17h00': 'Afternoon',
    '18h00': 'Evening',
    '19h00': 'Evening',
    '20h00': 'Evening',
    '21h00': 'Night',
    '22h00': 'Night',
    '23h00': 'Night',
    'Morning': 'Morning',
    'Afternoon': 'Afternoon',
    'Evening': 'Evening',
    'Night': 'Night',
}
shark_df['Time'] = shark_df['Time'].map(time_mapping)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\1031052387.py:31: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['Time'] = shark_df['Time'].map(time_mapping)

# %%
filtered_df.head(3)
# Out:
#    Year        Type    Country             State  Activity Sex Age  \
# 0  2024  Unprovoked  AUSTRALIA        Queensland  Swimming   F  13
# 2  2024  Unprovoked        USA            Hawaii  Swimming   F  11
# 6  2024  Unprovoked  AUSTRALIA  New  South Wales  Swimming   F  29
#
#                                      Injury       Time        Species   \
# 0  Minor injuries to back, abdomen and legs  Afternoon     Tiger shark
# 2                  Lacerations to left foot        NaN  3' to 4' shark
# 6                          Right leg bitten    Evening      Bull shark
#
#    is_fatal
# 0     False
# 2     False
# 6     False

# %%
top_activities = ["Surfing", "Swimming", "Fishing", "Spearfishing" "Snorkeling ", "Wading", "Diving"]
filtered_activities_df = shark_df[shark_df['Activity'].isin(top_activities)]
filtered_activities_df["Activity"].replace("Spearfishing", "Fishing")
filtered_activities_df["Activity"] = filtered_activities_df["Activity"].replace("Spearfishing", "Fishing")
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\152097501.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_activities_df["Activity"] = filtered_activities_df["Activity"].replace("Spearfishing", "Fishing")

# %%
filtered_activities_df['is_fatal'] = filtered_activities_df['is_fatal'].map({True: 'Fatal', False:'Non_Fatal'})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\1174570558.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   filtered_activities_df['is_fatal'] = filtered_activities_df['is_fatal'].map({True: 'Fatal', False:'Non_Fatal'})

# %%
filtered_activities_df
# Out:
#       Year        Type             Country              State  Activity Sex  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland  Swimming   F
# 1     2024  Unprovoked                 USA             Hawaii   Surfing   M
# 2     2024  Unprovoked                 USA             Hawaii  Swimming   F
# 4     2024  Unprovoked               INDIA        Maharashtra   Fishing   M
# 6     2024  Unprovoked           AUSTRALIA   New  South Wales  Swimming   F
# ...    ...         ...                 ...                ...       ...  ..
# 6937     0  Unprovoked           AUSTRALIA                NaN   Fishing   M
# 6938     0  Unprovoked           AUSTRALIA    New South Wales  Swimming   M
# 6939     0  Unprovoked           AUSTRALIA  Western Australia    Diving   M
# 6941     0  Unprovoked                 USA     North Carolina  Swimming   M
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province  Swimming   M
#
# ...

# %%
df_shark_sliced_age = shark_df.iloc[0:1000]
df_shark_sliced_age
# Out:
#       Year        Type     Country              State  \
# 0     2024  Unprovoked   AUSTRALIA         Queensland
# 1     2024  Unprovoked         USA             Hawaii
# 2     2024  Unprovoked         USA             Hawaii
# 3     2024  Unprovoked   AUSTRALIA  Western Australia
# 4     2024  Unprovoked       INDIA        Maharashtra
# ...    ...         ...         ...                ...
# 996   2015  Unprovoked  COSTA RICA         Guanacaste
# 997   2015         NaN   AUSTRALIA           Victoria
# 998   2015  Unprovoked         USA            Florida
# 999   2015         NaN         USA     South Carolina
# 1000  2015  Unprovoked   AUSTRALIA           Tasmania
#
#                       Activity Sex  Age  \
# 0                     Swimming   F   13
# 1                      Surfing   M  NaN
# 2                     Swimming   F   11
# 3                          NaN   F   46
# 4                      Fishing   M   32
# ...                        ...  ..  ...
# ...

# %%
df_shark_sliced_age['Age'] = pd.to_numeric(df_shark_sliced_age['Age'], errors='coerce')
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\1140776592.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced_age['Age'] = pd.to_numeric(df_shark_sliced_age['Age'], errors='coerce')

# %%
df_shark_sliced_age['Age'] = df_shark_sliced_age['Age'].fillna(df_shark_sliced_age['Age'].mean())
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\3022015252.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced_age['Age'] = df_shark_sliced_age['Age'].fillna(df_shark_sliced_age['Age'].mean())

# %%
df_shark_sliced_age['Age'].astype(int)
# Out:
# 0       13
# 1       32
# 2       11
# 3       46
# 4       32
#         ..
# 996     47
# 997     40
# 998     25
# 999     35
# 1000    46
# Name: Age, Length: 1000, dtype: int32

# %%
bins= [0, 12, 19, 60, 100]
labels = ['Child', 'Teen', 'Adult', 'Senior']
df_shark_sliced_age['age_group'] = pd.cut(df_shark_sliced_age['Age'],bins=bins, labels=labels,right=True)
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\3078755652.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_shark_sliced_age['age_group'] = pd.cut(df_shark_sliced_age['Age'],bins=bins, labels=labels,right=True)

# %%
df_shark_sliced_age = df_shark_sliced_age.drop(columns='Age')

# %%
df_shark_sliced_age
# Out:
#       Year        Type     Country              State  \
# 0     2024  Unprovoked   AUSTRALIA         Queensland
# 1     2024  Unprovoked         USA             Hawaii
# 2     2024  Unprovoked         USA             Hawaii
# 3     2024  Unprovoked   AUSTRALIA  Western Australia
# 4     2024  Unprovoked       INDIA        Maharashtra
# ...    ...         ...         ...                ...
# 996   2015  Unprovoked  COSTA RICA         Guanacaste
# 997   2015         NaN   AUSTRALIA           Victoria
# 998   2015  Unprovoked         USA            Florida
# 999   2015         NaN         USA     South Carolina
# 1000  2015  Unprovoked   AUSTRALIA           Tasmania
#
#                       Activity Sex  \
# 0                     Swimming   F
# 1                      Surfing   M
# 2                     Swimming   F
# 3                          NaN   F
# 4                      Fishing   M
# ...                        ...  ..
# 996                    Surfing   M
# ...

# %%
filtered_years_df = shark_df[(shark_df['Year'] >= 2000) & (shark_df['Year'] <= 2024)]

# %%
filtered_years_df
# Out:
#       Year        Type      Country               State  \
# 0     2024  Unprovoked    AUSTRALIA          Queensland
# 1     2024  Unprovoked          USA              Hawaii
# 2     2024  Unprovoked          USA              Hawaii
# 3     2024  Unprovoked    AUSTRALIA   Western Australia
# 4     2024  Unprovoked        INDIA         Maharashtra
# ...    ...         ...          ...                 ...
# 2689  2000  Unprovoked  NEW ZEALAND        South Island
# 2690  2000  Unprovoked    AUSTRALIA     South Australia
# 2691  2000         NaN      REUNION                 NaN
# 2692  2000  Unprovoked     THAILAND  Phang nga Province
# 2693  2000         NaN          USA             Florida
#
#                            Activity Sex  Age  \
# 0                          Swimming   F   13
# 1                           Surfing   M  NaN
# 2                          Swimming   F   11
# 3                               NaN   F   46
# 4                           Fishing   M   32
# ...

# %%
top5_countries = ['USA', 'AUSTRALIA', 'SOUTH AFRICA', 'NEW ZEALAND', 'BAHAMAS']

top5_countries_df = shark_df[shark_df['Country'].isin(top5_countries)]

# %%
top5_countries_df
# Out:
#       Year        Type    Country              State      Activity Sex  Age  \
# 0     2024  Unprovoked  AUSTRALIA         Queensland      Swimming   F   13
# 1     2024  Unprovoked        USA             Hawaii       Surfing   M  NaN
# 2     2024  Unprovoked        USA             Hawaii      Swimming   F   11
# 3     2024  Unprovoked  AUSTRALIA  Western Australia           NaN   F   46
# 6     2024  Unprovoked  AUSTRALIA   New  South Wales      Swimming   F   29
# ...    ...         ...        ...                ...           ...  ..  ...
# 6937     0  Unprovoked  AUSTRALIA                NaN       Fishing   M  NaN
# 6938     0  Unprovoked  AUSTRALIA    New South Wales      Swimming   M  NaN
# 6939     0  Unprovoked  AUSTRALIA  Western Australia        Diving   M  NaN
# 6940     0  Unprovoked  AUSTRALIA  Western Australia  Pearl diving   M  NaN
# 6941     0  Unprovoked        USA     North Carolina      Swimming   M  NaN
#
# ...

# %%
#Graph for the top5 attacked countries
top5_countries_df['Country'].value_counts().plot.pie(autopct='%1.1f%%', colors=['yellow', 'green', 'lightcoral', 'blue', 'red'])
# Out:
# <Axes: ylabel='count'>

# %%
import seaborn as sns

#Graph for the attacks of the last 24 years

sns.histplot(filtered_years_df['Year'], bins=25, color='red')
# Out:
# c:\Users\USER\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='Year', ylabel='Count'>

# %%
sns.countplot(x='Sex', data=shark_df)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
#Pivot table of deaths by activity

pivot_activies = filtered_activities_df.pivot_table(index='Activity', columns='is_fatal', values=['Type'], aggfunc='count')

# %%
pivot_activies
# Out:
#           Type
# is_fatal Fatal Non_Fatal
# Activity
# Diving      21       104
# Fishing     43       302
# Surfing     63      1010
# Swimming   315       563
# Wading      15       148

# %%
shark_df['is_fatal'] = shark_df['is_fatal'].map({True: 'Fatal', False:'Non_Fatal'})
# Out:
# C:\Users\USER\AppData\Local\Temp\ipykernel_3720\1749171565.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   shark_df['is_fatal'] = shark_df['is_fatal'].map({True: 'Fatal', False:'Non_Fatal'})

# %%
shark_df
# Out:
#       Year        Type             Country              State      Activity  \
# 0     2024  Unprovoked           AUSTRALIA         Queensland      Swimming
# 1     2024  Unprovoked                 USA             Hawaii       Surfing
# 2     2024  Unprovoked                 USA             Hawaii      Swimming
# 3     2024  Unprovoked           AUSTRALIA  Western Australia           NaN
# 4     2024  Unprovoked               INDIA        Maharashtra       Fishing
# ...    ...         ...                 ...                ...           ...
# 6939     0  Unprovoked           AUSTRALIA  Western Australia        Diving
# 6940     0  Unprovoked           AUSTRALIA  Western Australia  Pearl diving
# 6941     0  Unprovoked                 USA     North Carolina      Swimming
# 6942     0  Unprovoked              PANAMA                NaN           NaN
# 6943     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province      Swimming
#
# ...

# %%
shark_df['Time'].value_counts().plot.pie(autopct='%1.1f%%')
# Out:
# <Axes: ylabel='count'>
